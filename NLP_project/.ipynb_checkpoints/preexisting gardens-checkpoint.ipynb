# %%
import os 

import numpy as np
import pandas as pd
import folium as folium
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import folium
from folium import plugins

# %%
preexisting = pd.read_csv('gardens.locations.csv',encoding='ISO-8859-1')
preexisting
# Out:
#                                    Name  \
# 0          1st and Elm Community Garden
# 1                                   NaN
# 2             Altadena Community Garden
# 3                                   NaN
# 4               Arleta Community Garden
# ..                                  ...
# 192                        Wattles Farm
# 193                                 NaN
# 194                   Winston Smoyer CG
# 195                                 NaN
# 196  Yamazaki Memorial Community Garden
#
#                                                Address        Lat        Long
# 0      1st and Elm Community Garden\n417 E. 1st Street  34.053700 -118.298990
# 1                                                  NaN        NaN         NaN
# 2           3330 N. Lincoln Avenue\nAltadena, CA 91001  34.201270 -118.157370
# 3                                                  NaN        NaN         NaN
# 4    8800 Canterbury Avenue\nSan Fernando Valley, C...  34.201270 -118.378030
# ..                                                 ...        ...         ...
# 192       1714 N. Curson Avenue\nLos Angeles, CA 90046  34.102265 -118.354928
# 193                                                NaN        NaN         NaN
# 194                1006 Clay Court\nAlhambra, CA 91801  34.094691 -118.113333
# 195                                                NaN        NaN         NaN
# 196      961 S. Mariposa Avenue\nLos Angeles, CA 90006  34.053811 -118.299036
#
# [197 rows x 4 columns]

# %%
preexisting = preexisting.dropna()

preexisting.head(20)
# Out:
#                                                  Name  \
# 0                        1st and Elm Community Garden
# 2                           Altadena Community Garden
# 4                             Arleta Community Garden
# 6                       Baldwin Park Community Garden
# 8                                    Baldwin Park WIC
# 10                      Bell Gardens Community Garden
# 12                     Bougainvillea Community Garden
# 14                               Center Street Garden
# 16  City of Santa Monica Euclid Park Community Garden
# 18  City of Santa Monica Main Street Community Garden
# 20   City of Santa Monica Park Drive Community Garden
# 22                     Columbia Park Community Garden
# 24                          Crenshaw Community Garden
# 26                       Culver City Community Garden
# 28                      Dan McKenzie Community Garden
# 30                       Diamond Bar Community Garden
# 32                    Eagle Rockdale Community Garden
# 34                          Eastwind Community Garden
# 36                         El Sereno Community Garden
# 38                        Elm Avenue Community Garden
#
#                                               Address        Lat        Long
# 0     1st and Elm Community Garden\n417 E. 1st Street  34.053700 -118.298990
# 2          3330 N. Lincoln Avenue\nAltadena, CA 91001  34.201270 -118.157370
# 4   8800 Canterbury Avenue\nSan Fernando Valley, C...  34.201270 -118.378030
# 6           13067 Bess Avenue\nBaldwin Park, CA 91706  34.065680 -117.989220
# 8          3601 Puente Avenue\nBaldwin Park, CA 91706  34.077850 -117.953980
# 10             8000 Park Lane\nBell Gardens, CA 90201  33.959232 -118.155262
# 12  E. 103rd Street & Grape Street\nLos Angeles, C...  33.960144 -118.236218
# 14             196 E. Center Street\nPomona, CA 91767  34.061414 -117.748270
# 16         1525 Euclid Street\nSanta Monica, CA 90404  34.021666 -118.484561
# 18           2300 Main Street\nSanta Monica, CA 90405  34.004726 -118.486566
# 20            1400 Park Drive\nSanta Monica, CA 90404  34.030737 -118.474502
# 22              4045 190th Street\nTorrance, CA 90504  33.858396 -118.344528
# 24  1423 S. Crenshaw Boulevard\nLos Angeles, CA 90019  34.046567 -118.327354
# 26      10860 Culver Boulevard\nCulver City, CA 90230  34.010792 -118.405021
# 28              4324 160th Street\nLawndale, CA 90260  33.885397 -118.350139
# 30  2335 S. Diamond Bar Boulevard\nDiamond Bar, CA...  33.982505 -117.829572
# 32        1003 Rockdale Avenue\nLos Angeles, CA 90041  34.134009 -118.188837
# 34      110 Eastwind Street\nMarina Del Rey, CA 90292  33.977123 -118.463298
# 36       5466 Huntington Drive\nLos Angeles, CA 90032  34.091816 -118.162637
# 38              44748 Elm Avenue\nLancaster, CA 93534  34.695104 -118.141478

# %%
import folium
from folium.plugins import MarkerCluster

# Starting coordinates
la = [34.0522, -118.2437]

# Create a Folium map object with Los Angeles as the default location
gardenmap = folium.Map(location=la, zoom_start=5)  # Adjust the zoom level as needed

# Create a MarkerCluster object
marker_cluster = MarkerCluster().add_to(gardenmap)

# Filter out rows with null values for latitude and longitude
df_filtered = preexisting.dropna(subset=['Lat', 'Long'])

# Iterate through the filtered DataFrame and add markers for each latitude and longitude pair
for index, row in df_filtered.iterrows():
    folium.Marker([row['Lat'], row['Long']]).add_to(marker_cluster)

gardenmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66b160dcda24d490ace525581475ef80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66b160dcda24d490ace525581475ef80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66b160dcda24d490ace525581475ef80 = L.map(
#                 &quot;map_66b160dcda24d490ace525581475ef80&quot;,
#                 {
#                     center: [34.0522, -118.2437],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f7cfbcdb1fc14fff7a09aff83b4de00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_66b160dcda24d490ace525581475ef80);
#
#
#             var marker_cluster_5c54a2e2b12d93fd177335f4376145b6 = L.markerClusterGroup(
#                 {}
#             );
#             map_66b160dcda24d490ace525581475ef80.addLayer(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_a831120550ead7bb334b8b56729bac65 = L.marker(
#                 [34.0537, -118.29899],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_872a30d54ab5bb4a2b84db25a387520a = L.marker(
#                 [34.20127, -118.15737],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_c5ee48779c8983da5d9e6bdeeac6186d = L.marker(
#                 [34.20127, -118.37803],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_c70f064d573a38dc807bfb3374de2fe2 = L.marker(
#                 [34.06568, -117.98922],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_651764c922a8035cda2181a7ce2583b3 = L.marker(
#                 [34.07785, -117.95398],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_a231cf5622ed162136fb5df2d5331113 = L.marker(
#                 [33.959232, -118.155262],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_a0d93c806178650ffe6363fbd0f1573a = L.marker(
#                 [33.960144, -118.236218],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_83c8799dcd6ddacb2c7a8c29c31838df = L.marker(
#                 [34.061414, -117.7482696],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_ecd8feb1e054cf61f941686a7614965f = L.marker(
#                 [34.0216662, -118.484561],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_c260d7ebcf273a6b6b9d535562974df3 = L.marker(
#                 [34.004726, -118.486566],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_1c15dae56b93c7878c4efb133a79a944 = L.marker(
#                 [34.0307373, -118.4745021],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_40026f1cb4ed3e6312073ce72a714bc3 = L.marker(
#                 [33.8583956, -118.344528],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_b987dcaa4c15fcdbb00b0d48a102b35b = L.marker(
#                 [34.046567, -118.327354],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_f18e6778c98ceb71b72992b7b3062058 = L.marker(
#                 [34.010792, -118.4050213],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_e93c01b55a03b58450ed3e4172b894c6 = L.marker(
#                 [33.8853967, -118.3501389],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);
#
#
#             var marker_1344fc9cbb342ac916eeb136cd049227 = L.marker(
#                 [33.9825048, -117.8295715],
#                 {}
#             ).addTo(marker_cluster_5c54a2e2b12d93fd177335f4376145b6);

# %%
gardenmap.save("gardenmap.html")
